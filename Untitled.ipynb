# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('hotel_booking.csv')

# %%
print(df)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
df.tail(5)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.drop("agent", axis=1)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
a=df.drop("company", axis = 1)

# %%
a.drop("agent", axis = 1)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
a.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             488
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df["reservation_status_date"]=pd.to_datetime(df["reservation_status_date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.drop(["company","agent"], axis = 1, inplace = True)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
df.dropna()
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
cp=df["is_canceled"].value_counts()
cp
# Out:
# 0    75166
# 1    44224
# Name: is_canceled, dtype: int64

# %%
plt.figure(figsize=(5,4))
plt.title("reservation count")
c=['r','b']
plt.bar(['not cancelled','canceled'],cp, color=c)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# there are aprox 75000 of booking is conformed but 44500 booking is cancelled which is almost 38% which is huge so we have to check what is the key factors due to which cancilation rate is highe

# %%
p=df["required_car_parking_spaces"].value_counts()
p
# Out:
# 0    111974
# 1      7383
# 2        28
# 3         3
# 8         2
# Name: required_car_parking_spaces, dtype: int64

# %% [markdown]
# # plt for cheching which hotel have max no. of cancelation

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='hotel',hue='is_canceled', data=df, palette='Blues')
plt.title("reservation status in different hotel", size = 20)
plt.xlabel('hotel')
plt.ylabel('count of reservation')
plt.legend(['notcanceled','canceled'])
plt.show()

# %% [markdown]
# this graph is shown the resurvation status in different hotel like resort and city hotel

# %%
rh=df[df['hotel']=='Resort Hotel']
rh.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
rh.tail(5)
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 40055  Resort Hotel            0        212               2017
# 40056  Resort Hotel            0        169               2017
# 40057  Resort Hotel            0        204               2017
# 40058  Resort Hotel            0        211               2017
# 40059  Resort Hotel            0        161               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 40055             August                        35                         31
# 40056             August                        35                         30
# 40057             August                        35                         29
# 40058             August                        35                         31
# 40059             August                        35                         31
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...

# %%
rh['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.722366
# 1    0.277634
# Name: is_canceled, dtype: float64

# %%
ch=df[df['hotel']=='City Hotel']
ch.head(5)
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 40060  City Hotel            0          6               2015
# 40061  City Hotel            1         88               2015
# 40062  City Hotel            1         65               2015
# 40063  City Hotel            1         92               2015
# 40064  City Hotel            1        100               2015
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 40060               July                        27                          1
# 40061               July                        27                          1
# 40062               July                        27                          1
# 40063               July                        27                          1
# 40064               July                        27                          2
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...

# %%
ch['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.58273
# 1    0.41727
# Name: is_canceled, dtype: float64

# %%
df['month']=df['reservation_status_date'].dt.month
plt.figure(figsize = (16,8))
sns.countplot(x='month', hue='is_canceled', data=df)
plt.xlabel('month')
plt.ylabel('is_canceled')
plt.legend(['not_canceled', 'canceled'])

# %%
m=df.groupby('month')['adr'].sum()
m
# Out:
# month
# 1      925150.97
# 2      822905.15
# 3      914961.01
# 4     1049184.46
# 5     1142384.37
# 6     1080564.32
# 7     1459561.93
# 8     1556784.76
# 9     1028397.53
# 10     948911.57
# 11     642400.21
# 12     586411.32
# Name: adr, dtype: float64

# %%
canceled=df[df['is_canceled']==1]
top_10_contries= canceled['country'].value_counts()[:10]
plt.pie(top_10_contries,autopct='%.2f', labels=top_10_contries.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x22157a29250>,
# ...
#  [Text(-0.6486479706231275, 0.8884007036278723, 'PRT'),
#   Text(-0.12429436280215385, -1.0929551277960163, 'GBR'),
#   Text(0.2797610009026121, -1.0638297713327864, 'ESP'),
#   Text(0.6083579436571936, -0.9164609170003873, 'FRA'),
#   Text(0.8245010439701849, -0.7281469827528474, 'ITA'),
#   Text(0.954958661809011, -0.5459431785780853, 'DEU'),
#   Text(1.0312772570969826, -0.38271035914190277, 'IRL'),
#   Text(1.0729095093498013, -0.24262148451192195, 'BRA'),
#   Text(1.0926181033926405, -0.12722295444875134, 'USA'),
#   Text(1.0992092846107648, -0.04170070293760958, 'BEL')],
#  [Text(-0.3538079839762513, 0.4845822019788394, '70.07'),
#   Text(-0.06779692516481119, -0.5961573424341907, '6.25'),
#   Text(0.15259690958324293, -0.580270784363338, '5.54'),
#   Text(0.33183160563119646, -0.49988777290930214, '4.92'),
#   Text(0.44972784216555534, -0.39717108150155306, '3.39'),
#   Text(0.520886542804915, -0.2977871883153192, '3.10'),
# ...

# %%
mp=df['market_segment'].value_counts(normalize=True)
mp
# Out:
# Online TA        0.473046
# Offline TA/TO    0.202856
# Groups           0.165935
# Direct           0.105587
# Corporate        0.044350
# Complementary    0.006223
# Aviation         0.001985
# Undefined        0.000017
# Name: market_segment, dtype: float64

# %%
plt.figure(figsize=(15,8))
plt.bar(['online','offline','groups','direct','corporate','complementary','aviation','undefined'],mp)
plt.title('no. of customer comes from diffrent modes')
plt.show()

# %% [markdown]
# maximum customer comes by online booking where hotels put wrong information some benifits which they dont have then after come and see customer is disapointed and canceled there reservation

# %% [markdown]
# so hotels  need to put a correct information on online portal and only put those information which they full fill

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='hotel', hue='is_repeated_guest',data=df)
plt.show()

# %% [markdown]
# reapeated ratio of both resort and hotel are low which is show that customers are not happy with there services specialy city hotel because in resort which is hot side city people hardly gon but for city hotel customers frequently travel and go in hotel and is customer like hotel services then they gone a specific place and there is viry low repeated value it means customers are not serisfiy or happy with there services so hotel need to improve there service quality or oppint some quality staff who are well educated and good in there respective filed

# %%
nc=df[df['is_canceled']==0]
g=nc.groupby('meal')['meal'].value_counts()
g
# Out:
# meal       meal
# BB         BB           57800
# FB         FB             320
# HB         HB            9479
# SC         SC            6684
# Undefined  Undefined      883
# Name: meal, dtype: int64

# %%
sns.countplot(x='meal',data=nc)
plt.title('the hotel whos reservation is not canceled is give which type of meal')
plt.xlabel('meal')
plt.ylabel('no. of counts')
plt.show()

# %% [markdown]
# there is a count of restaurent whose reservation is not canceled where they give which type of meal it means guest want BB meals

# %%
c=df[df['is_canceled']==1]
h=c.groupby('meal')['meal'].value_counts()
h
# Out:
# meal       meal
# BB         BB           34510
# FB         FB             478
# HB         HB            4984
# SC         SC            3966
# Undefined  Undefined      286
# Name: meal, dtype: int64

# %%
# Out:
#   Cell In[15], line 1
#     df['required_car_parking_spaces']value_counts()
#                                      ^
# SyntaxError: invalid syntax
